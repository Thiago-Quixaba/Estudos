# %% [markdown]
# Escreva um programa solicitado que o usuário digite um número e em seguida exiba esse número elevado ao cubo, o número digitado dividido por 3 e seu módulo por 2

# %%
number = float(input())
print(f"{number ** number}\n{number / 3}\n{number % 2}")
