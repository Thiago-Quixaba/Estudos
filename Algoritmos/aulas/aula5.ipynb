# %%
print(all(dia in {'domingo', 'segunda', 'terça', 'quarta', 'quinta', 'sexta', 'sabado'} for dia in ['segunda', 'domingo']))

# %%
print(sorted( set([1, 2, 3, 2, 4, 5, 3])))

# %%
A, B = {input() for _ in range(3)}, {input() for _ in range(3)}
print(A | B, A - B, len(A | B))

# %%
conjunto = {'a', 'b', 'c', 'd'}
conjunto.remove('b')
conjunto.add('e')
print('a' in conjunto)
# Out:
# True
