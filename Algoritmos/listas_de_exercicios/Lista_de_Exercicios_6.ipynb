# %% [markdown]
# **Campus:** Paulistana
# **Curso:** Tecnólogo em Análise e Desenvolvimento de Sistemas
# **Disciplina:** Algoritmos
# **Profº:** Julian Rodrigues Valério
# **Aluno:** Thiago Quixaba Campos de Macedo
#
# ---
#
# #### Lista de Exercícios – Conjuntos em Python
#
# Resolva a lista de exercícios abaixo utilizando conceitos de lógica de programação e conjuntos em Python.

# %% [markdown]
# 1° - Crie um conjunto com 5 nomes de cidades brasileiras e exiba seus elementos. Em seguida, exiba também o total de elementos presentes no conjunto.

# %%
cidades = {"Paulistana", "Acauã", "Picos", "Teresina", "São Paulos"}
print(cidades, len(cidades))
# Out:
# {'Picos', 'Paulistana', 'São Paulos', 'Teresina', 'Acauã'} 5

# %% [markdown]
# 2° - Dado o conjunto abaixo, solicite ao usuário um nome de animal e verifique se ele pertence ao conjunto. Exiba uma mensagem indicando se o elemento foi encontrado ou não.
#
# ```python
# animais = {"gato", "cachorro", "papagaio", "tartaruga", "hamster"}
# ```

# %%
print(input().lower() in {"gato", "cachorro", "papagaio", "tartaruga", "hamster"})
# Out:
# False

# %% [markdown]
# 3° - Crie um conjunto com as linguagens de programação: `Python`, `Java` e `C`. Em seguida:
# - a. Adicione as linguagens `JavaScript` e `Kotlin` ao conjunto
# - b. Remova a linguagem `C` do conjunto *(use `discard()` para evitar erro)*
# - c. Exiba o conjunto atualizado e a quantidade final de elementos

# %%
linguagens = {"Python", "Java", "C"}
linguagens.add("JavaScript")
linguagens.add("Kotlin")
linguagens.discard("C")
print(linguagens, len(linguagens))
# Out:
# {'JavaScript', 'Python', 'Java', 'Kotlin'} 4

# %% [markdown]
# 4° - Dada a lista abaixo, utilize um conjunto para remover os valores duplicados. Converta o resultado de volta para lista, ordene em ordem crescente e exiba o resultado final.
#
# ```python
# numeros = [4, 7, 2, 4, 9, 2, 1, 7, 5, 1, 9, 3]
# ```

# %%
print(list(set([4, 7, 2, 4, 9, 2, 1, 7, 5, 1, 9, 3])))
# Out:
# [1, 2, 3, 4, 5, 7, 9]

# %% [markdown]
# 5° - Dois grupos de alunos participaram de atividades diferentes. Crie dois conjuntos com os nomes abaixo e exiba todos os alunos que participaram de pelo menos uma das atividades, sem repetição.
#
# ```python
# grupo_a = {"Ana", "Bruno", "Carlos", "Diana"}
# grupo_b = {"Carlos", "Evelyn", "Felipe", "Ana", "Gabriela"}
# ```

# %%
grupo_a = {"Ana", "Bruno", "Carlos", "Diana"}
grupo_b = {"Carlos", "Evelyn", "Felipe", "Ana", "Gabriela"}

# %%
print(grupo_a | grupo_b)
# Out:
# {'Gabriela', 'Bruno', 'Felipe', 'Diana', 'Evelyn', 'Carlos', 'Ana'}

# %% [markdown]
# 6° - Utilizando os mesmos conjuntos `grupo_a` e `grupo_b` da questão anterior, descubra e exiba os alunos que participaram das duas atividades ao mesmo tempo.

# %%
print(grupo_a & grupo_b)
# Out:
# {'Carlos', 'Ana'}

# %% [markdown]
# 7° - Com base nos conjuntos `grupo_a` e `grupo_b` da questão 5:
# - a. Exiba os alunos que estão **APENAS** no `grupo_a` *(diferença)*
# - b. Exiba os alunos que estão **APENAS** no `grupo_b` *(diferença)*
# - c. Exiba os alunos que estão em um dos grupos, mas **NÃO** nos dois *(diferença simétrica)*

# %%
print(grupo_a - grupo_b, grupo_b - grupo_a, grupo_a ^ grupo_b)
# Out:
# {'Diana', 'Bruno'} {'Evelyn', 'Felipe', 'Gabriela'} {'Diana', 'Gabriela', 'Evelyn', 'Felipe', 'Bruno'}

# %% [markdown]
# 8° - Crie um conjunto com 8 números inteiros (positivos e negativos) de sua escolha.
# Percorra o conjunto e exiba separadamente:
# - a. Todos os números positivos do conjunto
# - b. Todos os números negativos do conjunto
# - c. A soma total de todos os elementos

# %%
conjunto = {i for i in range(4, -4, -1)}
print(f"Positivos: {','.join([str(i) for i in conjunto if i > 0])}\nNegativos: {','.join([str(i) for i in conjunto if i < 0])}\nSoma: {sum(conjunto)}")
# Out:
# Positivos: 1,2,3,4
# Negativos: -2,-3,-1
# Soma: 4

# %% [markdown]
# 9° - Dados os conjuntos abaixo, verifique e exiba:
#
# ```python
# disciplinas_obrigatorias = {"Algoritmos", "Cálculo", "Física", "POO", "Banco de Dados"}
# cursadas_pelo_aluno = {"Algoritmos", "Cálculo", "POO"}
# ```
#
# - a. O conjunto `cursadas_pelo_aluno` é subconjunto de `disciplinas_obrigatorias`?
# - b. O conjunto `disciplinas_obrigatorias` é superconjunto de `cursadas_pelo_aluno`?
# - c. Os dois conjuntos possuem elementos em comum?

# %%
disciplinas_obrigatorias = {"Algoritmos", "Cálculo", "Física", "POO", "Banco de Dados"}
cursadas_pelo_aluno = {"Algoritmos", "Cálculo", "POO"}

print(cursadas_pelo_aluno.issubset(disciplinas_obrigatorias), disciplinas_obrigatorias.issuperset(cursadas_pelo_aluno), bool(cursadas_pelo_aluno & disciplinas_obrigatorias))
# Out:
# True True True

# %% [markdown]
# 10° - Um sistema de controle de presença de um evento possui três listas de participantes de diferentes dias:
#
# ```python
# dia_1 = {"Lucas", "Mariana", "Pedro", "Sofia", "Thiago"}
# dia_2 = {"Mariana", "Pedro", "Julia", "Rafael", "Sofia"}
# dia_3 = {"Lucas", "Julia", "Thiago", "Beatriz", "Pedro"}
# ```
# Com base nesses dados, calcule e exiba:
# - a. O total de participantes únicos ao longo dos três dias
# - b. Os participantes que estiveram presentes nos três dias
# - c. Os participantes que foram apenas no dia 1 *(e não apareceram nos outros dias)*
# - d. Os participantes que estiveram em pelo menos dois dos três dias

# %%
dia_1 = {"Lucas", "Mariana", "Pedro", "Sofia", "Thiago"}
dia_2 = {"Mariana", "Pedro", "Julia", "Rafael", "Sofia"}
dia_3 = {"Lucas", "Julia", "Thiago", "Beatriz", "Pedro"}

print(len((dia_1 | dia_2 | dia_3) - ((dia_1 & dia_2) | (dia_2 & dia_3) | (dia_3 & dia_1))), dia_1 & dia_2 & dia_3, (dia_1 - dia_2) - dia_3, (dia_1 & dia_2) | (dia_2 & dia_3) | (dia_3 & dia_1))
# Out:
# 2 {'Pedro'} set() {'Julia', 'Mariana', 'Pedro', 'Sofia', 'Thiago', 'Lucas'}
